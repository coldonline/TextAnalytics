# %%
import pandas as pd 
import xml.etree.ElementTree as et 

xtree = et.parse("Stadiums.xml")
xroot = xtree.getroot() 

df_cols = ["stadiumID","stadium_name", "state", "country", "latitude", "longitude", "capacity"]
rows = []


for node in xroot:
    s_ID = node.find("StadiumID").text if node is not None else None
    s_name = node.find("Name").text if node is not None else None
    s_state = node.find("State").text if node is not None else None
    s_country = node.find("Country").text if node is not None else None
    s_cap = node.find("Capacity").text if node is not None else None
    s_lat = node.find("GeoLat").text if node is not None else None
    s_lon = node.find("GeoLong").text if node is not None else None

    rows.append({"stadiumID":s_ID,"stadium_name": s_name, 
                 "state": s_state, "country":s_country,
                 "latitude":s_lat, "longitude":s_lon, "capacity": s_cap})

out_df = pd.DataFrame(rows, columns = df_cols)

# %%
out_df
# Out:
#    stadiumID                     stadium_name state country   latitude  \
# 0          1                    New Era Field    NY     USA  42.773758
# 1          2                Hard Rock Stadium    FL     USA  25.957740
# 2          3                  MetLife Stadium    NJ     USA  40.813611
# 3          4                 Gillette Stadium    MA     USA  42.090866
# 4          5               Paul Brown Stadium    OH     USA  39.095309
# 5          6              FirstEnergy Stadium    OH     USA  41.505885
# 6          7                 M&T Bank Stadium    MD     USA  39.277985
# 7          8                      Heinz Field    PA     USA  40.446751
# 8          9                Lucas Oil Stadium    IN     USA  39.760056
# 9         10                  TIAA Bank Field    FL     USA  30.323813
# 10        11                      NRG Stadium    TX     USA  29.684722
# 11        12                   Nissan Stadium    TN     USA  36.166441
# 12        13     Broncos Stadium at Mile High    CO     USA  39.743936
# 13        14                 Qualcomm Stadium    CA     USA  32.783188
# 14        15                Arrowhead Stadium    MO     USA  39.049002
# 15        16                 Oakland Coliseum    CA     USA  37.751613
# 16        17                     AT&T Stadium    TX     USA  32.747778
# 17        18          Lincoln Financial Field    PA     USA  39.900771
# 18        19                      FedEx Field    MD     USA  38.907652
# 19        20                    Soldier Field    IL     USA  41.862320
# 20        21                       Ford Field    MI     USA  42.340021
# 21        22                    Lambeau Field    WI     USA  44.501389
# 22        23            Mall of America Field    MN      US  44.976000
# 23        24            Raymond James Stadium    FL     USA  27.975967
# 24        25                     Georgia Dome    GA     USA  33.757614
# 25        26          Bank of America Stadium    NC     USA  35.225808
# 26        27          Mercedes-Benz Superdome    LA     USA  29.950931
# 27        28                 Candlestick Park    CA      US  37.404108
# 28        29             U of Phoenix Stadium    AZ     USA  33.527558
# 29        30                Edward Jones Dome    MO     USA  38.632975
# 30        31                CenturyLink Field    WA     USA  47.595153
# 31        33                  Wembley Stadium  None      UK  51.555833
# 32        34                    Rogers Centre  None      CA  43.641590
# 33        35                  Fawcett Stadium    OH     USA  40.819822
# 34        36                 TCF Bank Stadium    MN     USA  44.976000
# 35        37                   Levi's Stadium    CA     USA  37.404108
# 36        38    Los Angeles Memorial Coliseum    CA     USA  34.014167
# 37        39            Camping World Stadium    FL     USA  25.958056
# 38        40               Twickenham Stadium  None      UK  51.455936
# 39        41                   Estadio Azteca  None     MEX  19.302861
# 40        42                U.S. Bank Stadium    MN     USA  44.974288
# 41        43                   StubHub Center    CA     USA  33.858663
# 42        45            Mercedes-Benz Stadium    GA     USA  33.755000
# 43        46  Tom Benson Hall of Fame Stadium    OH     USA  40.819880
# 44        47                Tottenham Stadium  None      UK  51.604444
# 45        48                    Aloha Stadium    HI     USA  21.372647
# 46        50            Investors Group Field  None      CA  49.807778
#
#       longitude capacity
# 0    -78.786837    73079
# 1    -80.238781    76100
# 2    -74.074444    82500
# 3    -71.264244    68756
# 4    -84.516003    65535
# 5    -81.699458    71516
# 6    -76.622788    71008
# 7    -80.015707    65050
# 8    -86.163806    67000
# 9    -81.637199    67246
# 10   -95.410707    71054
# 11   -86.771253     6914
# 12  -105.020097    76125
# 13  -117.119439    70561
# 14   -94.483864    76416
# 15  -122.200509    53200
# 16   -97.092778    80000
# 17   -75.167469    68532
# 18   -76.864479    85000
# 19   -87.616699    61500
# 20   -83.045777    65000
# 21   -88.061944    80750
# 22   -93.225000    64111
# 23   -82.503350    65890
# 24   -84.400972    74228
# 25   -80.852861    73778
# 26   -90.081364    73208
# 27  -121.970274    70207
# 28  -112.263036    63400
# 29   -90.188547    66000
# 30  -122.331625    67000
# 31    -0.279722    86000
# 32   -79.390028    86000
# 33   -81.398177    22375
# 34   -93.225000    50805
# 35  -121.970274    68500
# 36  -118.287778    93607
# 37   -80.238889    65000
# 38    -0.341516    82000
# 39   -99.150528    87000
# 40   -93.329728    66655
# 41  -118.256666    27000
# 42   -84.401000    71000
# 43   -81.398010     None
# 44    -0.066389    62062
# 45  -157.929821    50000
# 46   -97.143056    33134

# %%
import pandas as pd 
import xml.etree.ElementTree as et 

xtree = et.parse("Teams.xml")
xroot = xtree.getroot() 

df_cols = ["key","ID","Team","Name","conference","division","full_name","stadiumID"]
rows = []


for node in xroot.findall('Team'):
    
    t_key = node.find("Key").text if node is not None else None
    t_TeamID = node.find("TeamID").text if node is not None else None
    t_city = node.find("City").text if node is not None else None
    t_name = node.find("Name").text if node is not None else None
    t_conf = node.find("Conference").text if node is not None else None
    t_div = node.find("Division").text if node is not None else None
    t_full = node.find("FullName").text if node is not None else None
    t_s_ID = node.find("StadiumID").text if node is not None else None
    rows.append({"key": t_key, "ID": t_TeamID, 
             "Team": t_city, "Name":t_name,
             "conference":t_conf, "division":t_div, "full_name": t_full, "stadiumID":t_s_ID})
team_df = pd.DataFrame(rows, columns = df_cols)

# %%
team_df
# Out:
#     key  ID           Team        Name conference division  \
# 0   ARI   1        Arizona   Cardinals        NFC     West
# 1   ATL   2        Atlanta     Falcons        NFC    South
# 2   BAL   3      Baltimore      Ravens        AFC    North
# 3   BUF   4        Buffalo       Bills        AFC     East
# 4   CAR   5       Carolina    Panthers        NFC    South
# 5   CHI   6        Chicago       Bears        NFC    North
# 6   CIN   7     Cincinnati     Bengals        AFC    North
# 7   CLE   8      Cleveland      Browns        AFC    North
# 8   DAL   9         Dallas     Cowboys        NFC     East
# 9   DEN  10         Denver     Broncos        AFC     West
# 10  DET  11        Detroit       Lions        NFC    North
# 11   GB  12      Green Bay     Packers        NFC    North
# 12  HOU  13        Houston      Texans        AFC    South
# 13  IND  14   Indianapolis       Colts        AFC    South
# 14  JAX  15   Jacksonville     Jaguars        AFC    South
# 15   KC  16    Kansas City      Chiefs        AFC     West
# 16  LAC  29    Los Angeles    Chargers        AFC     West
# 17  LAR  32    Los Angeles        Rams        NFC     West
# 18  MIA  19          Miami    Dolphins        AFC     East
# 19  MIN  20      Minnesota     Vikings        NFC    North
# 20   NE  21    New England    Patriots        AFC     East
# 21   NO  22    New Orleans      Saints        NFC    South
# 22  NYG  23       New York      Giants        NFC     East
# 23  NYJ  24       New York        Jets        AFC     East
# 24  OAK  25        Oakland     Raiders        AFC     West
# 25  PHI  26   Philadelphia      Eagles        NFC     East
# 26  PIT  28     Pittsburgh    Steelers        AFC    North
# 27  SEA  30        Seattle    Seahawks        NFC     West
# 28   SF  31  San Francisco       49ers        NFC     West
# 29   TB  33      Tampa Bay  Buccaneers        NFC    South
# 30  TEN  34      Tennessee      Titans        AFC    South
# 31  WAS  35     Washington    Redskins        NFC     East
#
#                full_name stadiumID
# 0      Arizona Cardinals        29
# 1        Atlanta Falcons        45
# 2       Baltimore Ravens         7
# 3          Buffalo Bills         1
# 4      Carolina Panthers        26
# 5          Chicago Bears        20
# 6     Cincinnati Bengals         5
# 7       Cleveland Browns         6
# 8         Dallas Cowboys        17
# 9         Denver Broncos        13
# 10         Detroit Lions        21
# 11     Green Bay Packers        22
# 12        Houston Texans        11
# 13    Indianapolis Colts         9
# 14  Jacksonville Jaguars        10
# 15    Kansas City Chiefs        15
# 16  Los Angeles Chargers        43
# 17      Los Angeles Rams        38
# 18        Miami Dolphins         2
# 19     Minnesota Vikings        42
# 20  New England Patriots         4
# 21    New Orleans Saints        27
# 22       New York Giants         3
# 23         New York Jets         3
# 24       Oakland Raiders        16
# 25   Philadelphia Eagles        18
# 26   Pittsburgh Steelers         8
# 27      Seattle Seahawks        31
# 28   San Francisco 49ers        37
# 29  Tampa Bay Buccaneers        24
# 30      Tennessee Titans        12
# 31   Washington Redskins        19

# %%
teams_stadium = pd.merge(team_df,
                 out_df,
                 on='stadiumID')
teams_stadium
# Out:
#     key  ID           Team        Name conference division  \
# 0   ARI   1        Arizona   Cardinals        NFC     West
# 1   ATL   2        Atlanta     Falcons        NFC    South
# 2   BAL   3      Baltimore      Ravens        AFC    North
# 3   BUF   4        Buffalo       Bills        AFC     East
# 4   CAR   5       Carolina    Panthers        NFC    South
# 5   CHI   6        Chicago       Bears        NFC    North
# 6   CIN   7     Cincinnati     Bengals        AFC    North
# 7   CLE   8      Cleveland      Browns        AFC    North
# 8   DAL   9         Dallas     Cowboys        NFC     East
# 9   DEN  10         Denver     Broncos        AFC     West
# 10  DET  11        Detroit       Lions        NFC    North
# 11   GB  12      Green Bay     Packers        NFC    North
# 12  HOU  13        Houston      Texans        AFC    South
# 13  IND  14   Indianapolis       Colts        AFC    South
# 14  JAX  15   Jacksonville     Jaguars        AFC    South
# 15   KC  16    Kansas City      Chiefs        AFC     West
# 16  LAC  29    Los Angeles    Chargers        AFC     West
# 17  LAR  32    Los Angeles        Rams        NFC     West
# 18  MIA  19          Miami    Dolphins        AFC     East
# 19  MIN  20      Minnesota     Vikings        NFC    North
# 20   NE  21    New England    Patriots        AFC     East
# 21   NO  22    New Orleans      Saints        NFC    South
# 22  NYG  23       New York      Giants        NFC     East
# 23  NYJ  24       New York        Jets        AFC     East
# 24  OAK  25        Oakland     Raiders        AFC     West
# 25  PHI  26   Philadelphia      Eagles        NFC     East
# 26  PIT  28     Pittsburgh    Steelers        AFC    North
# 27  SEA  30        Seattle    Seahawks        NFC     West
# 28   SF  31  San Francisco       49ers        NFC     West
# 29   TB  33      Tampa Bay  Buccaneers        NFC    South
# 30  TEN  34      Tennessee      Titans        AFC    South
# 31  WAS  35     Washington    Redskins        NFC     East
#
#                full_name stadiumID                   stadium_name state  \
# 0      Arizona Cardinals        29           U of Phoenix Stadium    AZ
# 1        Atlanta Falcons        45          Mercedes-Benz Stadium    GA
# 2       Baltimore Ravens         7               M&T Bank Stadium    MD
# 3          Buffalo Bills         1                  New Era Field    NY
# 4      Carolina Panthers        26        Bank of America Stadium    NC
# 5          Chicago Bears        20                  Soldier Field    IL
# 6     Cincinnati Bengals         5             Paul Brown Stadium    OH
# 7       Cleveland Browns         6            FirstEnergy Stadium    OH
# 8         Dallas Cowboys        17                   AT&T Stadium    TX
# 9         Denver Broncos        13   Broncos Stadium at Mile High    CO
# 10         Detroit Lions        21                     Ford Field    MI
# 11     Green Bay Packers        22                  Lambeau Field    WI
# 12        Houston Texans        11                    NRG Stadium    TX
# 13    Indianapolis Colts         9              Lucas Oil Stadium    IN
# 14  Jacksonville Jaguars        10                TIAA Bank Field    FL
# 15    Kansas City Chiefs        15              Arrowhead Stadium    MO
# 16  Los Angeles Chargers        43                 StubHub Center    CA
# 17      Los Angeles Rams        38  Los Angeles Memorial Coliseum    CA
# 18        Miami Dolphins         2              Hard Rock Stadium    FL
# 19     Minnesota Vikings        42              U.S. Bank Stadium    MN
# 20  New England Patriots         4               Gillette Stadium    MA
# 21    New Orleans Saints        27        Mercedes-Benz Superdome    LA
# 22       New York Giants         3                MetLife Stadium    NJ
# 23         New York Jets         3                MetLife Stadium    NJ
# 24       Oakland Raiders        16               Oakland Coliseum    CA
# 25   Philadelphia Eagles        18        Lincoln Financial Field    PA
# 26   Pittsburgh Steelers         8                    Heinz Field    PA
# 27      Seattle Seahawks        31              CenturyLink Field    WA
# 28   San Francisco 49ers        37                 Levi's Stadium    CA
# 29  Tampa Bay Buccaneers        24          Raymond James Stadium    FL
# 30      Tennessee Titans        12                 Nissan Stadium    TN
# 31   Washington Redskins        19                    FedEx Field    MD
#
#    country   latitude    longitude capacity
# 0      USA  33.527558  -112.263036    63400
# 1      USA  33.755000   -84.401000    71000
# 2      USA  39.277985   -76.622788    71008
# 3      USA  42.773758   -78.786837    73079
# 4      USA  35.225808   -80.852861    73778
# 5      USA  41.862320   -87.616699    61500
# 6      USA  39.095309   -84.516003    65535
# 7      USA  41.505885   -81.699458    71516
# 8      USA  32.747778   -97.092778    80000
# 9      USA  39.743936  -105.020097    76125
# 10     USA  42.340021   -83.045777    65000
# 11     USA  44.501389   -88.061944    80750
# 12     USA  29.684722   -95.410707    71054
# 13     USA  39.760056   -86.163806    67000
# 14     USA  30.323813   -81.637199    67246
# 15     USA  39.049002   -94.483864    76416
# 16     USA  33.858663  -118.256666    27000
# 17     USA  34.014167  -118.287778    93607
# 18     USA  25.957740   -80.238781    76100
# 19     USA  44.974288   -93.329728    66655
# 20     USA  42.090866   -71.264244    68756
# 21     USA  29.950931   -90.081364    73208
# 22     USA  40.813611   -74.074444    82500
# 23     USA  40.813611   -74.074444    82500
# 24     USA  37.751613  -122.200509    53200
# 25     USA  39.900771   -75.167469    68532
# 26     USA  40.446751   -80.015707    65050
# 27     USA  47.595153  -122.331625    67000
# 28     USA  37.404108  -121.970274    68500
# 29     USA  27.975967   -82.503350    65890
# 30     USA  36.166441   -86.771253     6914
# 31     USA  38.907652   -76.864479    85000

# %%
attendance = pd.read_csv("Attendance.csv")
attendance.head()
# Out:
#                 Team      Metro                       Stadium  Home games  \
# 0     Dallas Cowboys     Dallas                  AT&T Stadium           8
# 1      New York Jets   New York               MetLife Stadium           8
# 2  Green Bay Packers  Green Bay                 Lambeau Field           8
# 3    New York Giants   New York               MetLife Stadium           8
# 4     Denver Broncos     Denver  Broncos Stadium at Mile High           8
#
#   Average attendance Total attendance Capacity percentage
# 0             91,620          732,958             114.50%
# 1             77,982          623,856             100.00%
# 2             77,835          622,677              95.60%
# 3             76,941          615,525              93.30%
# 4             76,446          611,571             100.40%

# %%
teams_attendance = pd.merge(teams_stadium,
                 attendance[['Team','Average attendance', 'Metro']],
                 left_on='full_name', right_on='Team')
teams_attendance=teams_attendance.drop('Team_y', axis =1 )
teams_attendance
# Out:
#     key  ID         Team_x        Name conference division  \
# 0   ARI   1        Arizona   Cardinals        NFC     West
# 1   ATL   2        Atlanta     Falcons        NFC    South
# 2   BAL   3      Baltimore      Ravens        AFC    North
# 3   BUF   4        Buffalo       Bills        AFC     East
# 4   CAR   5       Carolina    Panthers        NFC    South
# 5   CHI   6        Chicago       Bears        NFC    North
# 6   CIN   7     Cincinnati     Bengals        AFC    North
# 7   CLE   8      Cleveland      Browns        AFC    North
# 8   DAL   9         Dallas     Cowboys        NFC     East
# 9   DEN  10         Denver     Broncos        AFC     West
# 10  DET  11        Detroit       Lions        NFC    North
# 11   GB  12      Green Bay     Packers        NFC    North
# 12  HOU  13        Houston      Texans        AFC    South
# 13  IND  14   Indianapolis       Colts        AFC    South
# 14  JAX  15   Jacksonville     Jaguars        AFC    South
# 15   KC  16    Kansas City      Chiefs        AFC     West
# 16  LAC  29    Los Angeles    Chargers        AFC     West
# 17  LAR  32    Los Angeles        Rams        NFC     West
# 18  MIA  19          Miami    Dolphins        AFC     East
# 19  MIN  20      Minnesota     Vikings        NFC    North
# 20   NE  21    New England    Patriots        AFC     East
# 21   NO  22    New Orleans      Saints        NFC    South
# 22  NYG  23       New York      Giants        NFC     East
# 23  NYJ  24       New York        Jets        AFC     East
# 24  OAK  25        Oakland     Raiders        AFC     West
# 25  PHI  26   Philadelphia      Eagles        NFC     East
# 26  PIT  28     Pittsburgh    Steelers        AFC    North
# 27  SEA  30        Seattle    Seahawks        NFC     West
# 28   SF  31  San Francisco       49ers        NFC     West
# 29   TB  33      Tampa Bay  Buccaneers        NFC    South
# 30  TEN  34      Tennessee      Titans        AFC    South
# 31  WAS  35     Washington    Redskins        NFC     East
#
#                full_name stadiumID                   stadium_name state  \
# 0      Arizona Cardinals        29           U of Phoenix Stadium    AZ
# 1        Atlanta Falcons        45          Mercedes-Benz Stadium    GA
# 2       Baltimore Ravens         7               M&T Bank Stadium    MD
# 3          Buffalo Bills         1                  New Era Field    NY
# 4      Carolina Panthers        26        Bank of America Stadium    NC
# 5          Chicago Bears        20                  Soldier Field    IL
# 6     Cincinnati Bengals         5             Paul Brown Stadium    OH
# 7       Cleveland Browns         6            FirstEnergy Stadium    OH
# 8         Dallas Cowboys        17                   AT&T Stadium    TX
# 9         Denver Broncos        13   Broncos Stadium at Mile High    CO
# 10         Detroit Lions        21                     Ford Field    MI
# 11     Green Bay Packers        22                  Lambeau Field    WI
# 12        Houston Texans        11                    NRG Stadium    TX
# 13    Indianapolis Colts         9              Lucas Oil Stadium    IN
# 14  Jacksonville Jaguars        10                TIAA Bank Field    FL
# 15    Kansas City Chiefs        15              Arrowhead Stadium    MO
# 16  Los Angeles Chargers        43                 StubHub Center    CA
# 17      Los Angeles Rams        38  Los Angeles Memorial Coliseum    CA
# 18        Miami Dolphins         2              Hard Rock Stadium    FL
# 19     Minnesota Vikings        42              U.S. Bank Stadium    MN
# 20  New England Patriots         4               Gillette Stadium    MA
# 21    New Orleans Saints        27        Mercedes-Benz Superdome    LA
# 22       New York Giants         3                MetLife Stadium    NJ
# 23         New York Jets         3                MetLife Stadium    NJ
# 24       Oakland Raiders        16               Oakland Coliseum    CA
# 25   Philadelphia Eagles        18        Lincoln Financial Field    PA
# 26   Pittsburgh Steelers         8                    Heinz Field    PA
# 27      Seattle Seahawks        31              CenturyLink Field    WA
# 28   San Francisco 49ers        37                 Levi's Stadium    CA
# 29  Tampa Bay Buccaneers        24          Raymond James Stadium    FL
# 30      Tennessee Titans        12                 Nissan Stadium    TN
# 31   Washington Redskins        19                    FedEx Field    MD
#
#    country   latitude    longitude capacity Average attendance          Metro
# 0      USA  33.527558  -112.263036    63400             62,014       Glendale
# 1      USA  33.755000   -84.401000    71000             72,898        Atlanta
# 2      USA  39.277985   -76.622788    71008             70,431      Baltimore
# 3      USA  42.773758   -78.786837    73079             64,962        Buffalo
# 4      USA  35.225808   -80.852861    73778             73,773      Charlotte
# 5      USA  41.862320   -87.616699    61500             61,344        Chicago
# 6      USA  39.095309   -84.516003    65535             50,754     Cincinnati
# 7      USA  41.505885   -81.699458    71516             65,765      Cleveland
# 8      USA  32.747778   -97.092778    80000             91,620         Dallas
# 9      USA  39.743936  -105.020097    76125             76,446         Denver
# 10     USA  42.340021   -83.045777    65000             62,758        Detroit
# 11     USA  44.501389   -88.061944    80750             77,835      Green Bay
# 12     USA  29.684722   -95.410707    71054             71,805        Houston
# 13     USA  39.760056   -86.163806    67000             59,200   Indianapolis
# 14     USA  30.323813   -81.637199    67246             69,074   Jacksonville
# 15     USA  39.049002   -94.483864    76416             75,973    Kansas City
# 16     USA  33.858663  -118.256666    27000             32,768    Los Angeles
# 17     USA  34.014167  -118.287778    93607             72,430    Los Angeles
# 18     USA  25.957740   -80.238781    76100             65,560          Miami
# 19     USA  44.974288   -93.329728    66655             66,811      Minnesota
# 20     USA  42.090866   -71.264244    68756             65,878         Boston
# 21     USA  29.950931   -90.081364    73208             73,051    New Orleans
# 22     USA  40.813611   -74.074444    82500             76,941       New York
# 23     USA  40.813611   -74.074444    82500             77,982       New York
# 24     USA  37.751613  -122.200509    53200             57,919        Oakland
# 25     USA  39.900771   -75.167469    68532             69,696   Philadelphia
# 26     USA  40.446751   -80.015707    65050             63,456     Pittsburgh
# 27     USA  47.595153  -122.331625    67000             69,001        Seattle
# 28     USA  37.404108  -121.970274    68500             69,149  San Francisco
# 29     USA  27.975967   -82.503350    65890             54,357      Tampa Bay
# 30     USA  36.166441   -86.771253     6914             64,520      Nashville
# 31     USA  38.907652   -76.864479    85000             61,028     Washington

# %%
x = pd.merge(out_df,
                            team_df, 
                            on='stadiumID',how = "left")
x =x[x['key'].isna()]
stadium_no_team = x.iloc[:,:7]

# %%
stadium_no_team
# Out:
#    stadiumID                     stadium_name state country   latitude  \
# 14        14                 Qualcomm Stadium    CA     USA  32.783188
# 23        23            Mall of America Field    MN      US  44.976000
# 25        25                     Georgia Dome    GA     USA  33.757614
# 28        28                 Candlestick Park    CA      US  37.404108
# 30        30                Edward Jones Dome    MO     USA  38.632975
# 32        33                  Wembley Stadium  None      UK  51.555833
# 33        34                    Rogers Centre  None      CA  43.641590
# 34        35                  Fawcett Stadium    OH     USA  40.819822
# 35        36                 TCF Bank Stadium    MN     USA  44.976000
# 38        39            Camping World Stadium    FL     USA  25.958056
# 39        40               Twickenham Stadium  None      UK  51.455936
# 40        41                   Estadio Azteca  None     MEX  19.302861
# 44        46  Tom Benson Hall of Fame Stadium    OH     USA  40.819880
# 45        47                Tottenham Stadium  None      UK  51.604444
# 46        48                    Aloha Stadium    HI     USA  21.372647
# 47        50            Investors Group Field  None      CA  49.807778
#
#       longitude capacity
# 14  -117.119439    70561
# 23   -93.225000    64111
# 25   -84.400972    74228
# 28  -121.970274    70207
# 30   -90.188547    66000
# 32    -0.279722    86000
# 33   -79.390028    86000
# 34   -81.398177    22375
# 35   -93.225000    50805
# 38   -80.238889    65000
# 39    -0.341516    82000
# 40   -99.150528    87000
# 44   -81.398010     None
# 45    -0.066389    62062
# 46  -157.929821    50000
# 47   -97.143056    33134

# %%
# teams_attendance.to_csv('teams_with_stadium.csv')
# stadium_no_team.to_csv('stadiums_without_a_team.csv')

# %%
us_cities = pd.read_csv('us_cities.txt')
top_cities = us_cities[:300]

# %%
city_team = pd.merge(teams_attendance,
                 top_cities,
                 left_on='Metro', right_on='city')
city_team=city_team.drop('Metro', axis =1 )

# %%
city_team = city_team.drop_duplicates('full_name', keep='first')
city_team
# Out:
#     key  ID         Team_x       Name conference division  \
# 0   ARI   1        Arizona  Cardinals        NFC     West
# 2   ATL   2        Atlanta    Falcons        NFC    South
# 3   BAL   3      Baltimore     Ravens        AFC    North
# 4   BUF   4        Buffalo      Bills        AFC     East
# 5   CAR   5       Carolina   Panthers        NFC    South
# 6   CHI   6        Chicago      Bears        NFC    North
# 7   CIN   7     Cincinnati    Bengals        AFC    North
# 8   CLE   8      Cleveland     Browns        AFC    North
# 9   DAL   9         Dallas    Cowboys        NFC     East
# 10  DEN  10         Denver    Broncos        AFC     West
# 11  DET  11        Detroit      Lions        NFC    North
# 12   GB  12      Green Bay    Packers        NFC    North
# 13  HOU  13        Houston     Texans        AFC    South
# 14  IND  14   Indianapolis      Colts        AFC    South
# 15  JAX  15   Jacksonville    Jaguars        AFC    South
# 17   KC  16    Kansas City     Chiefs        AFC     West
# 19  LAC  29    Los Angeles   Chargers        AFC     West
# 20  LAR  32    Los Angeles       Rams        NFC     West
# 21  MIA  19          Miami   Dolphins        AFC     East
# 22   NE  21    New England   Patriots        AFC     East
# 23   NO  22    New Orleans     Saints        NFC    South
# 24  NYG  23       New York     Giants        NFC     East
# 25  NYJ  24       New York       Jets        AFC     East
# 26  OAK  25        Oakland    Raiders        AFC     West
# 27  PHI  26   Philadelphia     Eagles        NFC     East
# 28  PIT  28     Pittsburgh   Steelers        AFC    North
# 29  SEA  30        Seattle   Seahawks        NFC     West
# 30   SF  31  San Francisco      49ers        NFC     West
# 31  WAS  35     Washington   Redskins        NFC     East
#
#                full_name stadiumID                   stadium_name state_x  \
# 0      Arizona Cardinals        29           U of Phoenix Stadium      AZ
# 2        Atlanta Falcons        45          Mercedes-Benz Stadium      GA
# 3       Baltimore Ravens         7               M&T Bank Stadium      MD
# 4          Buffalo Bills         1                  New Era Field      NY
# 5      Carolina Panthers        26        Bank of America Stadium      NC
# 6          Chicago Bears        20                  Soldier Field      IL
# 7     Cincinnati Bengals         5             Paul Brown Stadium      OH
# 8       Cleveland Browns         6            FirstEnergy Stadium      OH
# 9         Dallas Cowboys        17                   AT&T Stadium      TX
# 10        Denver Broncos        13   Broncos Stadium at Mile High      CO
# 11         Detroit Lions        21                     Ford Field      MI
# 12     Green Bay Packers        22                  Lambeau Field      WI
# 13        Houston Texans        11                    NRG Stadium      TX
# 14    Indianapolis Colts         9              Lucas Oil Stadium      IN
# 15  Jacksonville Jaguars        10                TIAA Bank Field      FL
# 17    Kansas City Chiefs        15              Arrowhead Stadium      MO
# 19  Los Angeles Chargers        43                 StubHub Center      CA
# 20      Los Angeles Rams        38  Los Angeles Memorial Coliseum      CA
# 21        Miami Dolphins         2              Hard Rock Stadium      FL
# 22  New England Patriots         4               Gillette Stadium      MA
# 23    New Orleans Saints        27        Mercedes-Benz Superdome      LA
# 24       New York Giants         3                MetLife Stadium      NJ
# 25         New York Jets         3                MetLife Stadium      NJ
# 26       Oakland Raiders        16               Oakland Coliseum      CA
# 27   Philadelphia Eagles        18        Lincoln Financial Field      PA
# 28   Pittsburgh Steelers         8                    Heinz Field      PA
# 29      Seattle Seahawks        31              CenturyLink Field      WA
# 30   San Francisco 49ers        37                 Levi's Stadium      CA
# 31   Washington Redskins        19                    FedEx Field      MD
#
#    country   latitude    longitude capacity Average attendance rank  \
# 0      USA  33.527558  -112.263036    63400             62,014   87
# 2      USA  33.755000   -84.401000    71000             72,898   40
# 3      USA  39.277985   -76.622788    71008             70,431   26
# 4      USA  42.773758   -78.786837    73079             64,962   73
# 5      USA  35.225808   -80.852861    73778             73,773   16
# 6      USA  41.862320   -87.616699    61500             61,344    3
# 7      USA  39.095309   -84.516003    65535             50,754   65
# 8      USA  41.505885   -81.699458    71516             65,765   48
# 9      USA  32.747778   -97.092778    80000             91,620    9
# 10     USA  39.743936  -105.020097    76125             76,446   22
# 11     USA  42.340021   -83.045777    65000             62,758   18
# 12     USA  44.501389   -88.061944    80750             77,835  272
# 13     USA  29.684722   -95.410707    71054             71,805    4
# 14     USA  39.760056   -86.163806    67000             59,200   12
# 15     USA  30.323813   -81.637199    67246             69,074   13
# 17     USA  39.049002   -94.483864    76416             75,973   37
# 19     USA  33.858663  -118.256666    27000             32,768    2
# 20     USA  34.014167  -118.287778    93607             72,430    2
# 21     USA  25.957740   -80.238781    76100             65,560   44
# 22     USA  42.090866   -71.264244    68756             65,878   24
# 23     USA  29.950931   -90.081364    73208             73,051   51
# 24     USA  40.813611   -74.074444    82500             76,941    1
# 25     USA  40.813611   -74.074444    82500             77,982    1
# 26     USA  37.751613  -122.200509    53200             57,919   45
# 27     USA  39.900771   -75.167469    68532             69,696    5
# 28     USA  40.446751   -80.015707    65050             63,456   62
# 29     USA  47.595153  -122.331625    67000             69,001   21
# 30     USA  37.404108  -121.970274    68500             69,149   14
# 31     USA  38.907652   -76.864479    85000             61,028   23
#
#              city               state_y population 2000-2013 growth
# 0        Glendale               Arizona     234632             5.7%
# 2         Atlanta               Georgia     447841             6.2%
# 3       Baltimore              Maryland     622104            -4.0%
# 4         Buffalo              New York     258959           -11.3%
# 5       Charlotte        North Carolina     792862            39.1%
# 6         Chicago              Illinois    2718782            -6.1%
# 7      Cincinnati                  Ohio     297517           -10.1%
# 8       Cleveland                  Ohio     390113           -18.1%
# 9          Dallas                 Texas    1257676             5.6%
# 10         Denver              Colorado     649495            16.7%
# 11        Detroit              Michigan     688701           -27.1%
# 12      Green Bay             Wisconsin     104779             1.9%
# 13        Houston                 Texas    2195914            11.0%
# 14   Indianapolis               Indiana     843393             7.8%
# 15   Jacksonville               Florida     842583            14.3%
# 17    Kansas City              Missouri     467007             5.5%
# 19    Los Angeles            California    3884307             4.8%
# 20    Los Angeles            California    3884307             4.8%
# 21          Miami               Florida     417650            14.9%
# 22         Boston         Massachusetts     645966             9.4%
# 23    New Orleans             Louisiana     378715           -21.6%
# 24       New York              New York    8405837             4.8%
# 25       New York              New York    8405837             4.8%
# 26        Oakland            California     406253             1.3%
# 27   Philadelphia          Pennsylvania    1553165             2.6%
# 28     Pittsburgh          Pennsylvania     305841            -8.3%
# 29        Seattle            Washington     652405            15.6%
# 30  San Francisco            California     837442             7.7%
# 31     Washington  District of Columbia     646449            13.0%

# %%
top_50_cities = us_cities[:50]
city_with_team = city_team['city'].tolist()
top_50_cities_city = top_50_cities['city'].tolist()
top_50_cities_no =top_50_cities_city[top_50_cities_city not in city_with_team]

# %%
top_50_cities_no = []
for city in top_50_cities_city:
    if city in city_with_team:
        continue
    else: 
        top_50_cities_no.append(city)
top_50_cities_no

# %%
top_50_cities[top_50_cities['city'].isin([top_50_cities_no])]
# Out:
# Empty DataFrame
# Columns: [rank, city, state, population, 2000-2013 growth]
# Index: []

# %%
top_50_series_no = pd.Series(top_50_cities_no)
top_50_series_no = pd.DataFrame(top_50_series_no).reset_index()
top_50_series_no.columns = ['index','city']
top_50_series_no=top_50_series_no.drop('index', axis =1 )
city_50_no_team = pd.merge(top_50_cities, top_50_series_no,
                          on = 'city')
city_50_no_team
# Out:
#    rank                         city           state population  \
# 0     6                      Phoenix         Arizona    1513367
# 1     7                  San Antonio           Texas    1409019
# 2     8                    San Diego      California    1355896
# 3    10                     San Jose      California     998537
# 4    11                       Austin           Texas     885400
# 5    15                     Columbus            Ohio     822553
# 6    17                   Fort Worth           Texas     792727
# 7    19                      El Paso           Texas     674433
# 8    20                      Memphis       Tennessee     653450
# 9    25           Nashville-Davidson       Tennessee     634464
# 10   27                Oklahoma City        Oklahoma     610613
# 11   28  Louisville/Jefferson County        Kentucky     609893
# 12   29                     Portland          Oregon     609456
# 13   30                    Las Vegas          Nevada     603488
# 14   31                    Milwaukee       Wisconsin     599164
# 15   32                  Albuquerque      New Mexico     556495
# 16   33                       Tucson         Arizona     526116
# 17   34                       Fresno      California     509924
# 18   35                   Sacramento      California     479686
# 19   36                   Long Beach      California     469428
# 20   38                         Mesa         Arizona     457587
# 21   39               Virginia Beach        Virginia     448479
# 22   41             Colorado Springs        Colorado     439886
# 23   42                        Omaha        Nebraska     434353
# 24   43                      Raleigh  North Carolina     431746
# 25   46                  Minneapolis       Minnesota     400070
# 26   47                        Tulsa        Oklahoma     398121
# 27   49                      Wichita          Kansas     386552
# 28   50                    Arlington           Texas     379577
#
#    2000-2013 growth
# 0             14.0%
# 1             21.0%
# 2             10.5%
# 3             10.5%
# 4             31.7%
# 5             14.8%
# 6             45.1%
# 7             19.4%
# 8             -5.3%
# 9             16.2%
# 10            20.2%
# 11            10.0%
# 12            15.0%
# 13            24.5%
# 14             0.3%
# 15            23.5%
# 16             7.5%
# 17            18.3%
# 18            17.2%
# 19             1.5%
# 20            13.5%
# 21             5.1%
# 22            21.4%
# 23             5.9%
# 24            48.7%
# 25             4.5%
# 26             1.3%
# 27             9.7%
# 28            13.3%

# %%
city_50_no_team = pd.merge(top_50_cities, top_50_series_no,
                          on = 'city')
city_50_no_team.drop([3,6,9,19,20,28]) #Manually removing cities part of metro with teams
# Out:
#    rank                         city           state population  \
# 0     6                      Phoenix         Arizona    1513367
# 1     7                  San Antonio           Texas    1409019
# 2     8                    San Diego      California    1355896
# 4    11                       Austin           Texas     885400
# 5    15                     Columbus            Ohio     822553
# 7    19                      El Paso           Texas     674433
# 8    20                      Memphis       Tennessee     653450
# 10   27                Oklahoma City        Oklahoma     610613
# 11   28  Louisville/Jefferson County        Kentucky     609893
# 12   29                     Portland          Oregon     609456
# 13   30                    Las Vegas          Nevada     603488
# 14   31                    Milwaukee       Wisconsin     599164
# 15   32                  Albuquerque      New Mexico     556495
# 16   33                       Tucson         Arizona     526116
# 17   34                       Fresno      California     509924
# 18   35                   Sacramento      California     479686
# 20   38                         Mesa         Arizona     457587
# 21   39               Virginia Beach        Virginia     448479
# 22   41             Colorado Springs        Colorado     439886
# 23   42                        Omaha        Nebraska     434353
# 24   43                      Raleigh  North Carolina     431746
# 25   46                  Minneapolis       Minnesota     400070
# 26   47                        Tulsa        Oklahoma     398121
# 27   49                      Wichita          Kansas     386552
#
#    2000-2013 growth
# 0             14.0%
# 1             21.0%
# 2             10.5%
# 4             31.7%
# 5             14.8%
# 7             19.4%
# 8             -5.3%
# 10            20.2%
# 11            10.0%
# 12            15.0%
# 13            24.5%
# 14             0.3%
# 15            23.5%
# 16             7.5%
# 17            18.3%
# 18            17.2%
# 20            13.5%
# 21             5.1%
# 22            21.4%
# 23             5.9%
# 24            48.7%
# 25             4.5%
# 26             1.3%
# 27             9.7%
